# %%
import pymongo
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from bson.json_util import dumps
myclient = pymongo.MongoClient("mongodb+srv://Timhore_123:Timhore123@cluster0.hj64h.mongodb.net/") # server mongoDB
mydb = myclient["Dataset"] # nama database
mycol = mydb["kc_house_data"] # nama collection
query = mycol.find() # query yang dijalankan menhasilkan data tipe cursor
list_query = list(query) # konversi cursor menjadi list
json_data = dumps(list_query, indent = 2)

# %%
df = pd.read_json(json_data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            21613 non-null  object
#  1   id             21613 non-null  int64
#  2   date           21613 non-null  datetime64[ns]
#  3   price          21613 non-null  int64
#  4   bedrooms       21613 non-null  int64
#  5   bathrooms      21613 non-null  float64
#  6   sqft_living    21613 non-null  int64
#  7   sqft_lot       21613 non-null  int64
#  8   floors         21613 non-null  float64
#  9   waterfront     21613 non-null  int64
#  10  view           21613 non-null  int64
#  11  condition      21613 non-null  int64
#  12  grade          21613 non-null  int64
#  13  sqft_above     21613 non-null  int64
#  14  sqft_basement  21613 non-null  int64
#  15  yr_built       21613 non-null  int64
#  16  yr_renovated   21613 non-null  int64
#  17  zipcode        21613 non-null  int64
#  18  lat            21613 non-null  float64
#  19  long           21613 non-null  float64
#  20  sqft_living15  21613 non-null  int64
#  21  sqft_lot15     21613 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(16), object(1)
# memory usage: 3.6+ MB

# %%
df.drop(['_id', 'date', 'floors', 'view', 'sqft_basement', 'sqft_lot',"yr_renovated","zipcode","lat","long","sqft_living15","sqft_lot15","waterfront","view","condition","sqft_above","sqft_basement"],inplace=True, axis=1)
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.373120e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.638765e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  1.000000e+00      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.200000e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.400000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#               grade      yr_built
# count  21613.000000  21613.000000
# mean       7.656873   1971.005136
# std        1.175459     29.373411
# min        1.000000   1900.000000
# 25%        7.000000   1951.000000
# 50%        7.000000   1975.000000
# 75%        8.000000   1997.000000
# max       13.000000   2015.000000

# %%
df['bathrooms'] = df['bathrooms'].astype('int')
df['bedrooms'] = df['bedrooms'].replace(33,3)

# %%
df.index[df['yr_built'] == 0]
# Out:
# Int64Index([], dtype='int64')

# %%
df.index[df['sqft_living'] == 0]
# Out:
# Int64Index([], dtype='int64')

# %%
df.index[df['grade'] == 0]
# Out:
# Int64Index([], dtype='int64')

# %%
df.index[df['price'] == 0]
# Out:
# Int64Index([], dtype='int64')

# %%
df.index[df['bedrooms'] == 0]
# Out:
# Int64Index([875, 3119, 3467, 4868, 6994, 8477, 8484, 9773, 9854, 12653, 14423,
#             18379, 19452],
#            dtype='int64')

# %%
df.index[df['bathrooms'] == 0]
# Out:
# Int64Index([  208,   264,   350,   465,   569,   860,   875,  1149,  1168,
#              1389,  1484,  1971,  1975,  2261,  2680,  3031,  3119,  3223,
#              3332,  3582,  3690,  3805,  4203,  4252,  4390,  5204,  5630,
#              5832,  6102,  6779,  6994,  7606,  7636,  8213,  8597,  8623,
#              9231,  9502,  9641,  9773,  9794,  9820,  9821,  9831,  9854,
#             10424, 10480, 10481, 10741, 10845, 11381, 11656, 11674, 12041,
#             12050, 12075, 12415, 12570, 12869, 13010, 14224, 14423, 14466,
#             15040, 15330, 15381, 16067, 16340, 16842, 16981, 17394, 17984,
#             18013, 18037, 18046, 18379, 18481, 18508, 18727, 18990, 19198,
#             19344, 19452, 20017, 21610, 21612],
#            dtype='int64')

# %%
df.drop(df.index[df['bedrooms'] == 0], inplace = True)
df.drop(df.index[df['bathrooms'] == 0], inplace = True)

# %%
df.shape
# Out:
# (21522, 7)

# %%
df['bathrooms'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 8, 7])

# %%
#menghitung jumlah missing value
df.isna().sum()
# Out:
# id             0
# price          0
# bedrooms       0
# bathrooms      0
# sqft_living    0
# grade          0
# yr_built       0
# dtype: int64

# %%
#Data analysis bedroom
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['bedrooms'])
f.add_subplot(1,2,2)
plt.boxplot(df['bedrooms'])
plt.show()
# Out:
# C:\Users\user\AppData\Roaming\Python\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Data analysis bathroom
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['bathrooms'])
f.add_subplot(1,2,2)
plt.boxplot(df['bathrooms'])
plt.show()
# Out:
# C:\Users\user\AppData\Roaming\Python\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Data analysis sqft_living.
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['sqft_living'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['sqft_living'])
plt.show()

# %%
#Data analysis condition.
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['grade'])
f.add_subplot(1,2,2)
plt.boxplot(df['grade'])
plt.show()
# Out:
# C:\Users\user\AppData\Roaming\Python\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Data analysis yr_built.

f = plt.figure(figsize=(20,8))
f.add_subplot(1,2,1)
sns.countplot(df['yr_built'])
f.add_subplot(1,2,2)
plt.boxplot(df['yr_built'])
plt.show()
# Out:
# C:\Users\user\AppData\Roaming\Python\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Analysis antara independent variable & dependent variable
plt.figure(figsize=(10,8))
sns.pairplot(data=df, x_vars=['bedrooms', 'bathrooms', 'sqft_living', 'grade', 'yr_built'], y_vars=['price'], size=5, aspect=0.75)
# Out:
# C:\Users\user\AppData\Roaming\Python\Python310\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Mengetahui nilai korelasi dari independent variable dan dependent variable.
df.corr().style.background_gradient().set_precision(2)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19268\3294473991.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df.corr().style.background_gradient().set_precision(2)
# <style type="text/css">
# #T_234ef_row0_col0, #T_234ef_row1_col1, #T_234ef_row2_col2, #T_234ef_row3_col3, #T_234ef_row4_col4, #T_234ef_row5_col5, #T_234ef_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_234ef_row0_col1, #T_234ef_row0_col2, #T_234ef_row0_col3, #T_234ef_row0_col4, #T_234ef_row0_col5, #T_234ef_row0_col6, #T_234ef_row1_col0, #T_234ef_row4_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_234ef_row1_col2 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_234ef_row1_col3 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_234ef_row1_col4, #T_234ef_row4_col1, #T_234ef_row4_col3 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_234ef_row1_col5 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_234ef_row1_col6 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_234ef_row2_col0, #T_234ef_row3_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_234ef_row2_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_234ef_row2_col3 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_234ef_row2_col4 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_234ef_row2_col5 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_234ef_row2_col6 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_234ef_row3_col1 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_234ef_row3_col2 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_234ef_row3_col4 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_234ef_row3_col5 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_234ef_row3_col6 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_234ef_row4_col2 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_234ef_row4_col5 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_234ef_row4_col6 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_234ef_row5_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_234ef_row5_col1 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_234ef_row5_col2 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_234ef_row5_col3 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_234ef_row5_col4 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_234ef_row5_col6, #T_234ef_row6_col3 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_234ef_row6_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_234ef_row6_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_234ef_row6_col2 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_234ef_row6_col4 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_234ef_row6_col5 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# </style>
# <table id="T_234ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_234ef_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_234ef_level0_col1" class="col_heading level0 col1" >price</th>
#       <th id="T_234ef_level0_col2" class="col_heading level0 col2" >bedrooms</th>
#       <th id="T_234ef_level0_col3" class="col_heading level0 col3" >bathrooms</th>
#       <th id="T_234ef_level0_col4" class="col_heading level0 col4" >sqft_living</th>
#       <th id="T_234ef_level0_col5" class="col_heading level0 col5" >grade</th>
#       <th id="T_234ef_level0_col6" class="col_heading level0 col6" >yr_built</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_234ef_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_234ef_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_234ef_row0_col1" class="data row0 col1" >-0.02</td>
#       <td id="T_234ef_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_234ef_row0_col3" class="data row0 col3" >-0.00</td>
#       <td id="T_234ef_row0_col4" class="data row0 col4" >-0.01</td>
#       <td id="T_234ef_row0_col5" class="data row0 col5" >0.01</td>
#       <td id="T_234ef_row0_col6" class="data row0 col6" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_234ef_level0_row1" class="row_heading level0 row1" >price</th>
#       <td id="T_234ef_row1_col0" class="data row1 col0" >-0.02</td>
#       <td id="T_234ef_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_234ef_row1_col2" class="data row1 col2" >0.31</td>
#       <td id="T_234ef_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_234ef_row1_col4" class="data row1 col4" >0.69</td>
#       <td id="T_234ef_row1_col5" class="data row1 col5" >0.66</td>
#       <td id="T_234ef_row1_col6" class="data row1 col6" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_234ef_level0_row2" class="row_heading level0 row2" >bedrooms</th>
#       <td id="T_234ef_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_234ef_row2_col1" class="data row2 col1" >0.31</td>
#       <td id="T_234ef_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_234ef_row2_col3" class="data row2 col3" >0.47</td>
#       <td id="T_234ef_row2_col4" class="data row2 col4" >0.59</td>
#       <td id="T_234ef_row2_col5" class="data row2 col5" >0.36</td>
#       <td id="T_234ef_row2_col6" class="data row2 col6" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_234ef_level0_row3" class="row_heading level0 row3" >bathrooms</th>
#       <td id="T_234ef_row3_col0" class="data row3 col0" >-0.00</td>
#       <td id="T_234ef_row3_col1" class="data row3 col1" >0.50</td>
#       <td id="T_234ef_row3_col2" class="data row3 col2" >0.47</td>
#       <td id="T_234ef_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_234ef_row3_col4" class="data row3 col4" >0.70</td>
#       <td id="T_234ef_row3_col5" class="data row3 col5" >0.60</td>
#       <td id="T_234ef_row3_col6" class="data row3 col6" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_234ef_level0_row4" class="row_heading level0 row4" >sqft_living</th>
#       <td id="T_234ef_row4_col0" class="data row4 col0" >-0.01</td>
#       <td id="T_234ef_row4_col1" class="data row4 col1" >0.69</td>
#       <td id="T_234ef_row4_col2" class="data row4 col2" >0.59</td>
#       <td id="T_234ef_row4_col3" class="data row4 col3" >0.70</td>
#       <td id="T_234ef_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_234ef_row4_col5" class="data row4 col5" >0.76</td>
#       <td id="T_234ef_row4_col6" class="data row4 col6" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_234ef_level0_row5" class="row_heading level0 row5" >grade</th>
#       <td id="T_234ef_row5_col0" class="data row5 col0" >0.01</td>
#       <td id="T_234ef_row5_col1" class="data row5 col1" >0.66</td>
#       <td id="T_234ef_row5_col2" class="data row5 col2" >0.36</td>
#       <td id="T_234ef_row5_col3" class="data row5 col3" >0.60</td>
#       <td id="T_234ef_row5_col4" class="data row5 col4" >0.76</td>
#       <td id="T_234ef_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_234ef_row5_col6" class="data row5 col6" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_234ef_level0_row6" class="row_heading level0 row6" >yr_built</th>
#       <td id="T_234ef_row6_col0" class="data row6 col0" >0.02</td>
#       <td id="T_234ef_row6_col1" class="data row6 col1" >0.05</td>
#       <td id="T_234ef_row6_col2" class="data row6 col2" >0.16</td>
#       <td id="T_234ef_row6_col3" class="data row6 col3" >0.43</td>
#       <td id="T_234ef_row6_col4" class="data row6 col4" >0.32</td>
#       <td id="T_234ef_row6_col5" class="data row6 col5" >0.45</td>
#       <td id="T_234ef_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
x = df.drop(['price'], axis=1).values
y = df['price'].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)
plt.scatter(y_test, pred)

print(y_test[:2], pred[:2])
# Out:
# [600000. 335000.] [505432.88822001 495140.40799449]

# %%
r2_score = 1-np.sum((y_test-pred)**2)/np.sum((y_test-y_test.mean())**2)
print(f'{r2_score*100:.2f}%')
# Out:
# 57.58%
