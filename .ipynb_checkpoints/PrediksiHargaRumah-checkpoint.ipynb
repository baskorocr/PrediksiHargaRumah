# %%
import numpy as np
import pymongo
import pandas as pd

from bson.json_util import dumps
myclient = pymongo.MongoClient("mongodb+srv://Timhore_123:Timhore123@cluster0.hj64h.mongodb.net/") # server mongoDB
mydb = myclient["Dataset"] # nama database
mycol = mydb["house_data"] # nama collection
query = mycol.find() # query yang dijalankan menhasilkan data tipe cursor
list_query = list(query) # konversi cursor menjadi list
json_data = dumps(list_query, indent = 2)
df = pd.read_json(json_data)
df.isna().sum()
# Out:
# _id              0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.head()
# Out:
#                                     _id       date      price  bedrooms  \
# 0  {'$oid': '62c3a25fd6355f6f88bffcaf'} 2014-05-02   313000.0         3
# 1  {'$oid': '62c3a25fd6355f6f88bffcb0'} 2014-05-02  2384000.0         5
# 2  {'$oid': '62c3a25fd6355f6f88bffcb1'} 2014-05-02   342000.0         3
# 3  {'$oid': '62c3a25fd6355f6f88bffcb2'} 2014-05-02   420000.0         3
# 4  {'$oid': '62c3a25fd6355f6f88bffcb3'} 2014-05-02   550000.0         4
#
#    bathrooms  sqft_living  sqft_lot  floors  waterfront  view  condition  \
# 0       1.50         1340      7912     1.5           0     0          3
# 1       2.50         3650      9050     2.0           0     4          5
# 2       2.00         1930     11947     1.0           0     0          4
# 3       2.25         2000      8030     1.0           0     0          4
# 4       2.50         1940     10500     1.0           0     0          4
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0        1340              0      1955          2005
# 1        3370            280      1921             0
# 2        1930              0      1966             0
# 3        1000           1000      1963             0
# 4        1140            800      1976          1992
#
#                      street       city  statezip country
# 0      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1           709 W Blaine St    Seattle  WA 98119     USA
# 2  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3           857 170th Pl NE   Bellevue  WA 98008     USA
# 4         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
df.drop(['_id','country', 'date', 'floors', 'view', 'sqft_basement', 'yr_renovated', 'waterfront','city','street','statezip','sqft_above','sqft_lot'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        4600 non-null   float64
#  1   bedrooms     4600 non-null   int64
#  2   bathrooms    4600 non-null   float64
#  3   sqft_living  4600 non-null   int64
#  4   condition    4600 non-null   int64
#  5   yr_built     4600 non-null   int64
# dtypes: float64(2), int64(4)
# memory usage: 215.8 KB

# %%
#mencari outliners menggunakan standart score dengan treshold 2.7
z = abs((df - df.mean())/df.std(ddof=0))
print(z)
for col in df.columns:
    df.loc[z[col] > 2.7] = np.nan
# Out:
#          price  bedrooms  bathrooms  sqft_living  condition  yr_built
# 0     0.423864  0.441122   0.843204     0.829971   0.667112  0.531014
# 1     3.249598  1.759705   0.432802     1.568528   2.286416  1.674693
# 2     0.372424  0.441122   0.205201     0.217367   0.809652  0.161000
# 3     0.234071  0.441122   0.113800     0.144686   0.809652  0.261913
# 4     0.003482  0.659291   0.432802     0.206984   0.809652  0.175376
# ...        ...       ...        ...          ...        ...       ...
# 4595  0.432437  0.441122   0.524202     0.653458   0.809652  0.564651
# 4596  0.031271  0.441122   0.432802     0.705374   0.667112  0.410840
# 4597  0.239562  0.441122   0.432802     0.904009   0.667112  1.285418
# 4598  0.618268  0.659291   0.205201     0.051238   0.667112  0.108101
# 4599  0.587759  0.441122   0.432802     0.674224   0.809652  0.646303
#
# [4600 rows x 6 columns]

# %%
#menghapus outliner
print(df.isnull().sum())
df.dropna(inplace=True)

print(df.isnull().sum())
# Out:
# price          182
# bedrooms       182
# bathrooms      182
# sqft_living    182
# condition      182
# yr_built       182
# dtype: int64
# price          0
# bedrooms       0
# bathrooms      0
# sqft_living    0
# condition      0
# yr_built       0
# dtype: int64

# %%
#menghitung jumlah missing value
df.isna().sum()
# Out:
# price          0
# bedrooms       0
# bathrooms      0
# sqft_living    0
# condition      0
# yr_built       0
# dtype: int64

# %%
#menghapus baris yang terdapat missing value 
df.dropna(axis=0, how='all')
# Out:
#               price  bedrooms  bathrooms  sqft_living  condition  yr_built
# 0     313000.000000       3.0       1.50       1340.0        3.0    1955.0
# 2     342000.000000       3.0       2.00       1930.0        4.0    1966.0
# 3     420000.000000       3.0       2.25       2000.0        4.0    1963.0
# 4     550000.000000       4.0       2.50       1940.0        4.0    1976.0
# 5     490000.000000       2.0       1.00        880.0        3.0    1938.0
# ...             ...       ...        ...          ...        ...       ...
# 4595  308166.666667       3.0       1.75       1510.0        4.0    1954.0
# 4596  534333.333333       3.0       2.50       1460.0        3.0    1983.0
# 4597  416904.166667       3.0       2.50       3010.0        3.0    2009.0
# 4598  203400.000000       4.0       2.00       2090.0        3.0    1974.0
# 4599  220600.000000       3.0       2.50       1490.0        4.0    1990.0
#
# [4418 rows x 6 columns]

# %%
#Data analysis bedroom
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['bedrooms'])
f.add_subplot(1,2,2)
plt.boxplot(df['bedrooms'])
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Data analysis bathroom
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['bathrooms'])
f.add_subplot(1,2,2)
plt.boxplot(df['bathrooms'])
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Data analysis sqft_living.
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['sqft_living'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['sqft_living'])
plt.show()

# %%
#Data analysis condition.
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['condition'])
f.add_subplot(1,2,2)
plt.boxplot(df['condition'])
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Data analysis yr_built.

f = plt.figure(figsize=(20,8))
f.add_subplot(1,2,1)
sns.countplot(df['yr_built'])
f.add_subplot(1,2,2)
plt.boxplot(df['yr_built'])
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Analysis antara independent variable & dependent variable
plt.figure(figsize=(10,8))
sns.pairplot(data=df, x_vars=['bedrooms', 'bathrooms', 'sqft_living', 'condition', 'yr_built'], y_vars=['price'], size=5, aspect=0.75)
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Mengetahui nilai korelasi dari independent variable dan dependent variable.
df.corr().style.background_gradient().set_precision(2)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21584\3294473991.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df.corr().style.background_gradient().set_precision(2)
# <style type="text/css">
# #T_bd536_row0_col0, #T_bd536_row1_col1, #T_bd536_row2_col2, #T_bd536_row3_col3, #T_bd536_row4_col4, #T_bd536_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bd536_row0_col1 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_bd536_row0_col2 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_bd536_row0_col3 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_bd536_row0_col4 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_bd536_row0_col5 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_bd536_row1_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_bd536_row1_col2 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_bd536_row1_col3 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_bd536_row1_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_bd536_row1_col5 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_bd536_row2_col0 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_bd536_row2_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_bd536_row2_col3 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_bd536_row2_col4 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_bd536_row2_col5 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_bd536_row3_col0 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_bd536_row3_col1 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_bd536_row3_col2 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_bd536_row3_col4 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_bd536_row3_col5 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_bd536_row4_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_bd536_row4_col1, #T_bd536_row4_col2, #T_bd536_row4_col3, #T_bd536_row4_col5, #T_bd536_row5_col0, #T_bd536_row5_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bd536_row5_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_bd536_row5_col2 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_bd536_row5_col3 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# </style>
# <table id="T_bd536">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd536_level0_col0" class="col_heading level0 col0" >price</th>
#       <th id="T_bd536_level0_col1" class="col_heading level0 col1" >bedrooms</th>
#       <th id="T_bd536_level0_col2" class="col_heading level0 col2" >bathrooms</th>
#       <th id="T_bd536_level0_col3" class="col_heading level0 col3" >sqft_living</th>
#       <th id="T_bd536_level0_col4" class="col_heading level0 col4" >condition</th>
#       <th id="T_bd536_level0_col5" class="col_heading level0 col5" >yr_built</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd536_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_bd536_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_bd536_row0_col1" class="data row0 col1" >0.30</td>
#       <td id="T_bd536_row0_col2" class="data row0 col2" >0.47</td>
#       <td id="T_bd536_row0_col3" class="data row0 col3" >0.63</td>
#       <td id="T_bd536_row0_col4" class="data row0 col4" >0.05</td>
#       <td id="T_bd536_row0_col5" class="data row0 col5" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_bd536_level0_row1" class="row_heading level0 row1" >bedrooms</th>
#       <td id="T_bd536_row1_col0" class="data row1 col0" >0.30</td>
#       <td id="T_bd536_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_bd536_row1_col2" class="data row1 col2" >0.52</td>
#       <td id="T_bd536_row1_col3" class="data row1 col3" >0.60</td>
#       <td id="T_bd536_row1_col4" class="data row1 col4" >0.02</td>
#       <td id="T_bd536_row1_col5" class="data row1 col5" >0.18</td>
#     </tr>
#     <tr>
#       <th id="T_bd536_level0_row2" class="row_heading level0 row2" >bathrooms</th>
#       <td id="T_bd536_row2_col0" class="data row2 col0" >0.47</td>
#       <td id="T_bd536_row2_col1" class="data row2 col1" >0.52</td>
#       <td id="T_bd536_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_bd536_row2_col3" class="data row2 col3" >0.72</td>
#       <td id="T_bd536_row2_col4" class="data row2 col4" >-0.14</td>
#       <td id="T_bd536_row2_col5" class="data row2 col5" >0.51</td>
#     </tr>
#     <tr>
#       <th id="T_bd536_level0_row3" class="row_heading level0 row3" >sqft_living</th>
#       <td id="T_bd536_row3_col0" class="data row3 col0" >0.63</td>
#       <td id="T_bd536_row3_col1" class="data row3 col1" >0.60</td>
#       <td id="T_bd536_row3_col2" class="data row3 col2" >0.72</td>
#       <td id="T_bd536_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_bd536_row3_col4" class="data row3 col4" >-0.07</td>
#       <td id="T_bd536_row3_col5" class="data row3 col5" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_bd536_level0_row4" class="row_heading level0 row4" >condition</th>
#       <td id="T_bd536_row4_col0" class="data row4 col0" >0.05</td>
#       <td id="T_bd536_row4_col1" class="data row4 col1" >0.02</td>
#       <td id="T_bd536_row4_col2" class="data row4 col2" >-0.14</td>
#       <td id="T_bd536_row4_col3" class="data row4 col3" >-0.07</td>
#       <td id="T_bd536_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_bd536_row4_col5" class="data row4 col5" >-0.41</td>
#     </tr>
#     <tr>
#       <th id="T_bd536_level0_row5" class="row_heading level0 row5" >yr_built</th>
#       <td id="T_bd536_row5_col0" class="data row5 col0" >0.03</td>
#       <td id="T_bd536_row5_col1" class="data row5 col1" >0.18</td>
#       <td id="T_bd536_row5_col2" class="data row5 col2" >0.51</td>
#       <td id="T_bd536_row5_col3" class="data row5 col3" >0.32</td>
#       <td id="T_bd536_row5_col4" class="data row5 col4" >-0.41</td>
#       <td id="T_bd536_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>
